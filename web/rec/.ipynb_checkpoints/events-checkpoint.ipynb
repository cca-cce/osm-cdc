# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the TSV files into Pandas DataFrames
mouse_data = pd.read_csv("mouse_positions.tsv", sep="\t")
click_data = pd.read_csv("click_positions.tsv", sep="\t")
scroll_data = pd.read_csv("scroll_positions.tsv", sep="\t")

# Modify scroll_data: rename 'scroll_position' to 'y'
scroll_data = scroll_data.rename(columns={'scroll_position': 'y'})

# Insert a new column 'x' with zeros at index 1 in scroll_data
scroll_data.insert(1, 'x', 0)

# Add a column for event type to all DataFrames
mouse_data['event_type'] = 'mouse'
click_data['event_type'] = 'click'
scroll_data['event_type'] = 'scroll'

# Concatenate the DataFrames into a single DataFrame and sort by timestamp
combined_df = pd.concat([mouse_data, click_data, scroll_data], ignore_index=True)

# Convert timestamp strings to datetime in Pandas for sorting
combined_df['timestamp'] = pd.to_datetime(combined_df['timestamp'], format="%Y-%m-%d %H:%M:%S.%f")

# Sort the combined DataFrame by timestamp in ascending order
combined_df = combined_df.sort_values(by='timestamp').reset_index(drop=True)

# Initialize a variable to keep track of the cumulative scroll adjustment
cumulative_scroll = 0

# Adjust y values for mouse and click events based on scroll events
for index, row in combined_df.iterrows():
    if row['event_type'] == 'scroll':
        # Update new_scroll to the current scroll y value
        new_scroll = row['y']
        # Calculate the scroll delta
        scroll_delta = new_scroll - cumulative_scroll
        # Update cumulative_scroll for the next iteration
        cumulative_scroll = new_scroll
    elif row['event_type'] in ['mouse', 'click']:
        # Add the cumulative scroll value to the y position of mouse and click events
        combined_df.at[index, 'y'] += cumulative_scroll

# Filter the DataFrame to select only mouse and click events
mouse_events = combined_df[combined_df['event_type'] == 'mouse']
click_events = combined_df[combined_df['event_type'] == 'click']

# Plotting
plt.figure(figsize=(10, 6))

# Plot mouse movements as blue dots connected with lines
plt.plot(mouse_events['x'], mouse_events['y'], color='blue', marker='o', linestyle='-', linewidth=1, markersize=4, label='Mouse Path')

# Plot click events as red dots without connecting lines
plt.scatter(click_events['x'], click_events['y'], color='red', marker='o', label='Click Events')

# Invert the y-axis to place the origin at the top-left corner
plt.gca().invert_yaxis()

# Adding labels and title
plt.title('Mouse Movements and Click Events with Scroll Adjustment')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # testing

# %%
import pandas as pd

# Read the TSV files into Pandas DataFrames
mouse_data = pd.read_csv("mouse_positions.tsv", sep="\t")
click_data = pd.read_csv("click_positions.tsv", sep="\t")
scroll_data = pd.read_csv("scroll_positions.tsv", sep="\t")

# Modify scroll_data: rename 'scroll_position' to 'y'
scroll_data = scroll_data.rename(columns={'scroll_position': 'y'})

# Insert a new column 'x' with zeros at index 1 in scroll_data
scroll_data.insert(1, 'x', 0)

# Add a column for event type to all DataFrames
mouse_data['event_type'] = 'mouse'
click_data['event_type'] = 'click'
scroll_data['event_type'] = 'scroll'

# Concatenate the DataFrames into a single DataFrame and sort by timestamp
combined_df = pd.concat([mouse_data, click_data, scroll_data], ignore_index=True)

# Convert timestamp strings to datetime in Pandas for sorting
combined_df['timestamp'] = pd.to_datetime(combined_df['timestamp'], format="%Y-%m-%d %H:%M:%S.%f")

# Sort the combined DataFrame by timestamp in ascending order
combined_df = combined_df.sort_values(by='timestamp').reset_index(drop=True)

# Print the combined and sorted DataFrame
print(combined_df.head())

# Check the structure of the combined DataFrame
print(combined_df.info())

# %%
mouse_data.y.max()
# Out:
# np.int64(248)

# %%
click_data.y.max()
# Out:
# np.int64(241)

# %%
scroll_data.y.max()
# Out:
# np.float64(1989.0)

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame to select only mouse events
mouse_events = combined_df[combined_df['event_type'] == 'mouse']

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(mouse_events['x'], mouse_events['y'], color='blue', marker='o', linestyle='-', linewidth=1, markersize=4, label='Mouse Path')

# Adding labels and title
plt.title('Mouse Movements')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(mouse_events['x'], mouse_events['y'], color='blue', marker='o', linestyle='-', linewidth=1, markersize=4, label='Mouse Path')

# Invert the y-axis to place the origin at the top-left corner
plt.gca().invert_yaxis()

# Adding labels and title
plt.title('Mouse Movements with Origin at Top-Left')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
mouse_events.y.max()
# Out:
# np.float64(248.0)

# %%
# Initialize a variable to keep track of the cumulative scroll adjustment
cumulative_scroll = 0

# Adjust y values for mouse and click events based on scroll events
for index, row in combined_df.iterrows():
    if row['event_type'] == 'scroll':
        # Incrementally add the scroll y value to the cumulative scroll
        cumulative_scroll += row['y']
    elif row['event_type'] in ['mouse', 'click']:
        # Add the cumulative scroll value to the y position of mouse and click events
        combined_df.at[index, 'y'] += cumulative_scroll

# %%
# Initialize variables to keep track of scroll changes
old_scroll = 0

# Adjust y values for mouse and click events based on scroll events
for index, row in combined_df.iterrows():
    if row['event_type'] == 'scroll':
        # Update new_scroll to the current scroll y value
        new_scroll = row['y']
        # Calculate the scroll delta
        scroll_delta = new_scroll - old_scroll
        # Update old_scroll for the next iteration
        old_scroll = new_scroll
    elif row['event_type'] in ['mouse', 'click']:
        # Add the scroll delta to the y position of mouse and click events
        combined_df.at[index, 'y'] += old_scroll

# %%
# Filter the DataFrame to select only mouse events
mouse_events = combined_df[combined_df['event_type'] == 'mouse']

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(mouse_events['x'], mouse_events['y'], color='blue', marker='o', linestyle='-', linewidth=1, markersize=4, label='Mouse Path')

# Invert the y-axis to place the origin at the top-left corner
plt.gca().invert_yaxis()

# Adding labels and title
plt.title('Mouse Movements with Scroll Adjustment')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %%
cumulative_scroll
# Out:
# 39332.25

# %%
scroll_data
# Out:
#                                                   url  x        y  \
# 0   file:///home/sol-nhl/dev/cce-web/web/py/index....  0     3.00
# 1   file:///home/sol-nhl/dev/cce-web/web/py/index....  0    13.50
# 2   file:///home/sol-nhl/dev/cce-web/web/py/index....  0    30.00
# 3   file:///home/sol-nhl/dev/cce-web/web/py/index....  0    66.75
# 4   file:///home/sol-nhl/dev/cce-web/web/py/index....  0    84.75
# 5   file:///home/sol-nhl/dev/cce-web/web/py/index....  0   102.75
# 6   file:///home/sol-nhl/dev/cce-web/web/py/index....  0   119.25
# 7   file:///home/sol-nhl/dev/cce-web/web/py/index....  0   132.00
# 8   file:///home/sol-nhl/dev/cce-web/web/py/index....  0   143.25
# 9   file:///home/sol-nhl/dev/cce-web/web/py/index....  0   150.00
# 10  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   162.00
# 11  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   177.75
# 12  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   195.75
# 13  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   214.50
# 14  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   233.25
# 15  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   251.25
# 16  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   268.50
# 17  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   291.00
# 18  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   339.00
# 19  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   383.25
# 20  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   402.00
# 21  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   420.00
# 22  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   438.00
# 23  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   458.25
# 24  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   481.50
# 25  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   502.50
# 26  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   537.00
# 27  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   569.25
# 28  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   603.75
# 29  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   634.50
# 30  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   664.50
# 31  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   690.75
# 32  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   714.75
# 33  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   735.00
# 34  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   750.00
# 35  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   760.50
# 36  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   765.00
# 37  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   765.75
# 38  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   773.25
# 39  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   799.50
# 40  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   845.25
# 41  file:///home/sol-nhl/dev/cce-web/web/py/index....  0   922.50
# 42  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1016.25
# 43  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1098.00
# 44  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1167.00
# 45  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1239.00
# 46  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1298.25
# 47  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1346.25
# 48  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1372.50
# 49  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1377.00
# 50  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1389.75
# 51  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1417.50
# 52  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1491.00
# 53  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1673.25
# 54  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1875.75
# 55  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1986.75
# 56  file:///home/sol-nhl/dev/cce-web/web/py/index....  0  1989.00
#
#            user                timestamp event_type
# 0   some-string  2024-08-05 14:27:38.185     scroll
# 1   some-string  2024-08-05 14:27:38.201     scroll
# 2   some-string  2024-08-05 14:27:38.216     scroll
# 3   some-string  2024-08-05 14:27:38.235     scroll
# 4   some-string  2024-08-05 14:27:38.267     scroll
# 5   some-string  2024-08-05 14:27:38.285     scroll
# 6   some-string  2024-08-05 14:27:38.304     scroll
# 7   some-string  2024-08-05 14:27:38.316     scroll
# 8   some-string  2024-08-05 14:27:38.334     scroll
# 9   some-string  2024-08-05 14:27:38.364     scroll
# 10  some-string  2024-08-05 14:27:38.366     scroll
# 11  some-string  2024-08-05 14:27:38.384     scroll
# 12  some-string  2024-08-05 14:27:38.405     scroll
# 232  file:///home/sol-nhl/dev/cce-web/web/py/index....  455  2126.0
# 233  file:///home/sol-nhl/dev/cce-web/web/py/index....  456  2126.0
# 234  file:///home/sol-nhl/dev/cce-web/web/py/index....  456  2126.0
#
#             user               timestamp event_type
# 0    some-string 2024-08-05 14:27:31.581      mouse
# 1    some-string 2024-08-05 14:27:31.584      mouse
# 2    some-string 2024-08-05 14:27:31.597      mouse
# 3    some-string 2024-08-05 14:27:31.613      mouse
# 4    some-string 2024-08-05 14:27:31.628      mouse
# ..           ...                     ...        ...
# 230  some-string 2024-08-05 14:27:43.082      mouse
# 231  some-string 2024-08-05 14:27:43.083      mouse
# 232  some-string 2024-08-05 14:27:43.090      mouse
# 233  some-string 2024-08-05 14:27:43.107      mouse
# 234  some-string 2024-08-05 14:27:43.655      click
#
# [235 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the TSV files into Pandas DataFrames
mouse_data = pd.read_csv("mouse_positions.tsv", sep="\t")
click_data = pd.read_csv("click_positions.tsv", sep="\t")
scroll_data = pd.read_csv("scroll_positions.tsv", sep="\t")

# Modify scroll_data: rename 'scroll_position' to 'y'
scroll_data = scroll_data.rename(columns={'scroll_position': 'y'})

# Insert a new column 'x' with zeros at index 1 in scroll_data
scroll_data.insert(1, 'x', 0)

# Add a column for event type to all DataFrames
mouse_data['event_type'] = 'mouse'
click_data['event_type'] = 'click'
scroll_data['event_type'] = 'scroll'

# Concatenate the DataFrames into a single DataFrame and sort by timestamp
combined_df = pd.concat([mouse_data, click_data, scroll_data], ignore_index=True)

# Convert timestamp strings to datetime in Pandas for sorting
combined_df['timestamp'] = pd.to_datetime(combined_df['timestamp'], format="%Y-%m-%d %H:%M:%S.%f")

# Sort the combined DataFrame by timestamp in ascending order
combined_df = combined_df.sort_values(by='timestamp').reset_index(drop=True)

# Initialize variables to keep track of scroll changes
old_scroll = 0

# Adjust y values for mouse and click events based on scroll events
for index, row in combined_df.iterrows():
    if row['event_type'] == 'scroll':
        # Update new_scroll to the current scroll y value
        new_scroll = row['y']
        # Calculate the scroll delta
        scroll_delta = new_scroll - old_scroll
        # Update old_scroll for the next iteration
        old_scroll = new_scroll
    elif row['event_type'] in ['mouse', 'click']:
        # Add the scroll delta to the y position of mouse and click events
        combined_df.at[index, 'y'] += old_scroll

# Filter the DataFrame to select only mouse and click events
mouse_events = combined_df[combined_df['event_type'] == 'mouse']
click_events = combined_df[combined_df['event_type'] == 'click']

# Plotting
plt.figure(figsize=(10, 6))

# Plot mouse movements as blue dots connected with lines
plt.plot(mouse_events['x'], mouse_events['y'], color='blue', marker='o', linestyle='-', linewidth=1, markersize=4, label='Mouse Path')

# Plot click events as red dots without connecting lines
plt.scatter(click_events['x'], click_events['y'], color='red', marker='o', label='Click Events')

# Invert the y-axis to place the origin at the top-left corner
plt.gca().invert_yaxis()

# Adding labels and title
plt.title('Mouse Movements and Click Events with Scroll Adjustment')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.legend()

# Display the plot
plt.grid(True)
plt.show()
